# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
from IPython.display import display

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# from pandas import HDFStore, read_hdf
# from pathlib import Path

import pickle
import requests, json

# from tabulate import tabulate

pd.options.display.float_format = '{:,.3f}'.format
pd.set_option('display.max_columns', 500)

from catboost import CatBoostClassifier

import warnings
with warnings.catch_warnings():
    warnings.filterwarnings("ignore",category=DeprecationWarning)
    from sklearn import preprocessing

# %%
data_dir = './dataPool/'
csv_file = '1_CoverageGroupSuggestion.csv'

read_csv = data_dir + csv_file

# %%
df_group_raw = pd.read_csv(read_csv, encoding ='utf_8')

# %%
df_group_raw = df_group_raw.iloc[:, :6]

display (df_group_raw.head(3))
print(df_group_raw.shape)
# Out:
#   Group                                       CnaeSession  Uf  FundationDate  \
# 0    G1                                        CONSTRUÇÃO  ES           1990
# 1    G1  ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  RR           1991
# 2    G3                   SAÚDE HUMANA E SERVIÇOS SOCIAIS  SC           2015
#
#     Equity  RefYearMonth
# 0  7320000        201806
# 1  1500000        201802
# 2  1500000        201710
# (49999, 6)

# %%
for i in list(df_group_raw):
    print(i)
    print(df_group_raw[i].value_counts())
# Out:
# Group
# G2    10102
# G1    10057
# G4    10028
# G3     9989
# G5     9823
# Name: Group, dtype: int64
# CnaeSession
# ADMINISTRAÇÃO PÚBLICA, DEFESA E SEGURIDADE SOCIAL                    2463
# ELETRICIDADE E GÁS                                                   2450
# ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕES EXTRATERRITORIAIS    2445
# INDÚSTRIAS EXTRATIVAS                                                2441
# ATIVIDADES IMOBILIÁRIAS                                              2431
# ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS RELACIONADOS           2422
# EDUCAÇÃO                                                             2406
# ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS E DESCONTAMINAÇÃO     2396
# ALOJAMENTO E ALIMENTAÇÃO                                             2394
# COMÉRCIO; REPARAÇÃO DE VEÍCULOS AUTOMOTORES E MOTOCICLETAS           2388
# AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PESCA E AQÜICULTURA       2387
# OUTRAS ATIVIDADES DE SERVIÇOS                                        2387
# SAÚDE HUMANA E SERVIÇOS SOCIAIS                                      2376
# ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS                     2355
# CONSTRUÇÃO                                                           2346
# ARTES, CULTURA, ESPORTE E RECREAÇÃO                                  2337
# INFORMAÇÃO E COMUNICAÇÃO                                             2333
# INDÚSTRIAS DE TRANSFORMAÇÃO                                          2332
# ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEMENTARES                 2328
# SERVIÇOS DOMÉSTICOS                                                  2303
# TRANSPORTE, ARMAZENAGEM E CORREIO                                    2279
# Name: CnaeSession, dtype: int64
# Uf
# SC    1967
# MG    1930
# DF    1911
# AL    1906
# AM    1900
# PB    1897
# RO    1894
# MT    1881
# AC    1879
# GO    1879
# AP    1875
# ES    1869
# BA    1860
# MS    1856
# SE    1852
# TO    1849
# PE    1840
# RJ    1836
# RN    1828
# RS    1824
# CE    1819
# RR    1809
# PA    1800
# MA    1796
# PR    1756
# SP    1749
# PI    1737
# Name: Uf, dtype: int64
# FundationDate
# 1998    16550
# 2015     4894
# 1996     4804
# 1997     4734
# 1991     2451
# 1987     2429
# 1990     2405
# 2001     2387
# 1992     2353
# 2010     2347
# 1993     2343
# 2016     2302
# Name: FundationDate, dtype: int64
# Equity
# 2320000     13670
# 5320000      9148
# 1000000      9016
# 1500000      4604
# 15320000     4577
# 500000       4528
# 7320000      4456
# Name: Equity, dtype: int64
# RefYearMonth
# 201805    3962
# 201712    3929
# 201802    3889
# 201711    3884
# 201804    3870
# 201706    3854
# 201801    3834
# 201708    3819
# 201806    3817
# 201710    3815
# 201709    3793
# 201707    3781
# 201803    3752
# Name: RefYearMonth, dtype: int64

# %%
df = df_group_raw.iloc[:, :5]
df
# Out:
#       Group                                        CnaeSession  Uf  \
# 0        G1                                         CONSTRUÇÃO  ES
# 1        G1   ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  RR
# 2        G3                    SAÚDE HUMANA E SERVIÇOS SOCIAIS  SC
# 3        G3                                SERVIÇOS DOMÉSTICOS  PI
# 4        G4  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  RN
# 5        G2  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  RR
# 6        G5                ARTES, CULTURA, ESPORTE E RECREAÇÃO  CE
# 7        G4  ADMINISTRAÇÃO PÚBLICA, DEFESA E SEGURIDADE SOCIAL  AM
# 8        G3  ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEME...  SC
# 9        G1   ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  TO
# 10       G3                           ALOJAMENTO E ALIMENTAÇÃO  MA
# 11       G3                           ALOJAMENTO E ALIMENTAÇÃO  SE
# 12       G2                                 ELETRICIDADE E GÁS  AC
# 13       G3  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  BA
# 14       G2  ADMINISTRAÇÃO PÚBLICA, DEFESA E SEGURIDADE SOCIAL  AP
# 15       G2                                 ELETRICIDADE E GÁS  AP
# 16       G3                           INFORMAÇÃO E COMUNICAÇÃO  SP
# 17       G1                                           EDUCAÇÃO  PE
# 18       G5                                SERVIÇOS DOMÉSTICOS  RS
# 19       G4  ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS ...  MT
# 20       G2                                           EDUCAÇÃO  RN
# 21       G4                           INFORMAÇÃO E COMUNICAÇÃO  MT
# 22       G4  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  RN
# 23       G4                  TRANSPORTE, ARMAZENAGEM E CORREIO  AM
# 24       G2                      OUTRAS ATIVIDADES DE SERVIÇOS  AC
# 25       G3                            ATIVIDADES IMOBILIÁRIAS  SC
# 26       G2   ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  MG
# 27       G2   ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  SC
# 28       G1                           ALOJAMENTO E ALIMENTAÇÃO  RJ
# 29       G4  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...  AP
# ...     ...                                                ...  ..
# 49969    G5                                           EDUCAÇÃO  PA
# 49970    G3                        INDÚSTRIAS DE TRANSFORMAÇÃO  ES
# 49971    G4                        INDÚSTRIAS DE TRANSFORMAÇÃO  PA
# 49972    G3  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  PI
# 49973    G5                                 ELETRICIDADE E GÁS  PA
# 49974    G5                                 ELETRICIDADE E GÁS  AM
# 49975    G4                            ATIVIDADES IMOBILIÁRIAS  SC
# 49976    G1   ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  MG
# 49977    G1   ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  PA
# 49978    G4                                SERVIÇOS DOMÉSTICOS  RR
# 49979    G2  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  MT
# 49980    G2                ARTES, CULTURA, ESPORTE E RECREAÇÃO  SP
# 49981    G2  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  MA
# 49982    G2  ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...  PI
# 49983    G1                           ALOJAMENTO E ALIMENTAÇÃO  PI
# 49984    G3  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  MA
# 49985    G5  ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...  CE
# 49986    G1                ARTES, CULTURA, ESPORTE E RECREAÇÃO  RN
# 49987    G3                                SERVIÇOS DOMÉSTICOS  GO
# 49988    G4  ÁGUA, ESGOTO, ATIVIDADES DE GESTÃO DE RESÍDUOS...  AL
# 49989    G3                           INFORMAÇÃO E COMUNICAÇÃO  ES
# 49990    G5                      OUTRAS ATIVIDADES DE SERVIÇOS  SE
# 49991    G2  ATIVIDADES FINANCEIRAS, DE SEGUROS E SERVIÇOS ...  DF
# 49992    G5                            ATIVIDADES IMOBILIÁRIAS  PR
# 49993    G5                  TRANSPORTE, ARMAZENAGEM E CORREIO  AM
# 49994    G1                              INDÚSTRIAS EXTRATIVAS  PR
# 49995    G1                            ATIVIDADES IMOBILIÁRIAS  ES
# 49996    G3  ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...  RR
# 49997    G2  AGRICULTURA, PECUÁRIA, PRODUÇÃO FLORESTAL, PES...  ES
# 49998    G2                ARTES, CULTURA, ESPORTE E RECREAÇÃO  PB
#
#        FundationDate    Equity
# 0               1990   7320000
# 1               1991   1500000
# 2               2015   1500000
# 3               2001   1500000
# 4               1993   5320000
# 5               1998   5320000
# 6               1990   2320000
# 7               1998    500000
# 8               2016   5320000
# 9               1998   1500000
# 10              1996   1000000
# 11              2016   2320000
# 12              1998   2320000
# 13              1998   1000000
# 14              1998   5320000
# 15              1998   2320000
# 16              2015   1500000
# 17              1998   2320000
# 18              2016   2320000
# 19              1987  15320000
# 20              1998   2320000
# 21              2016   5320000
# 22              1998   1500000
# 23              1993   2320000
# 24              1993   2320000
# 25              1997   5320000
# 26              1998   1000000
# 27              2010   2320000
# 28              1998   2320000
# 29              1996   2320000
# ...              ...       ...
# 49969           1998   7320000
# 49970           2001   1000000
# 49971           1997   1000000
# 49972           2015   1000000
# 49973           2001   1500000
# 49974           2015   5320000
# 49975           1993   7320000
# 49976           1998  15320000
# 49977           1998   2320000
# 49978           1997   5320000
# 49979           1998   1500000
# 49980           2001  15320000
# 49981           2010   5320000
# 49982           1996   2320000
# 49983           1998   1000000
# 49984           1998  15320000
# 49985           1998   1000000
# 49986           1998   1000000
# 49987           1990   1500000
# 49988           1997   2320000
# 49989           2015   1000000
# 49990           1993   5320000
# 49991           1998    500000
# 49992           2010   1000000
# 49993           1998   5320000
# 49994           1998   5320000
# 49995           1990  15320000
# 49996           1998   2320000
# 49997           2016   1000000
# 49998           2015   1500000
#
# [49999 rows x 5 columns]

# %% [markdown]
# ## Features and label

# %%
df_data = df.drop(columns=['Group'])
df_label_cat = df.Group

# %%
display (df_data.head(3))
display (df_label_cat.head(3))
# Out:
#                                         CnaeSession  Uf  FundationDate  \
# 0                                        CONSTRUÇÃO  ES           1990
# 1  ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  RR           1991
# 2                   SAÚDE HUMANA E SERVIÇOS SOCIAIS  SC           2015
#
#     Equity
# 0  7320000
# 1  1500000
# 2  1500000
# 0    G1
# 1    G1
# 2    G3
# Name: Group, dtype: object

# %% [markdown]
# ## (Optional) One-hot encoding (No need for our current project)

# %%
from sklearn import preprocessing
from collections import defaultdict
d = defaultdict(preprocessing.LabelEncoder)
d
# Out:
# defaultdict(sklearn.preprocessing.label.LabelEncoder, {})

# %% [markdown]
# ### Assign encoder

# %%
df_dataEncoder = df.drop(columns=['Group','Equity'])[:4]
df_dataEncoder
# Out:
#                                         CnaeSession  Uf  FundationDate
# 0                                        CONSTRUÇÃO  ES           1990
# 1  ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  RR           1991
# 2                   SAÚDE HUMANA E SERVIÇOS SOCIAIS  SC           2015
# 3                               SERVIÇOS DOMÉSTICOS  PI           2001

# %%
df_encoded = df_dataEncoder.apply(lambda x: d[x.name].fit_transform(x))
display(df_encoded)
print(d)
print(d['CnaeSession'])
# Out:
#    CnaeSession  Uf  FundationDate
# 0            1   0              0
# 1            0   2              1
# 2            2   3              3
# 3            3   1              2
# defaultdict(<class 'sklearn.preprocessing.label.LabelEncoder'>, {'CnaeSession': LabelEncoder(), 'Uf': LabelEncoder(), 'FundationDate': LabelEncoder()})
# LabelEncoder()

# %%
df_encoded_rev = df_encoded.apply(lambda x: d[x.name].inverse_transform(x))
display(df_encoded_rev)
# Out:
#                                         CnaeSession  Uf  FundationDate
# 0                                        CONSTRUÇÃO  ES           1990
# 1  ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  RR           1991
# 2                   SAÚDE HUMANA E SERVIÇOS SOCIAIS  SC           2015
# 3                               SERVIÇOS DOMÉSTICOS  PI           2001

# %% [markdown]
# ### Feature mapping

# %%
class feature_mapping(object):
    def __init__(self, d, curr_feat):
        self.d = d
        self.curr_feat = curr_feat
    def getMapping(self):
        mapping_all = dict()
        for one_feat in self.curr_feat:
            mapping_all[one_feat] = dict(zip(d[one_feat].classes_, range(len(d[one_feat].classes_))))
#             mapping_all.append(dict(zip(d[one_feat].classes_, 
#                                     range(len(d[one_feat].classes_)))))          
        return mapping_all

# %%
myMap = feature_mapping(d, list(df_encoded))
display(myMap.getMapping())
print(myMap.getMapping()['CnaeSession'])
print({k:v for k, v in myMap.getMapping()['CnaeSession'].items() if v == 0})
# Out:
# {'CnaeSession': {'ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS': 0,
#   'CONSTRUÇÃO': 1,
#   'SAÚDE HUMANA E SERVIÇOS SOCIAIS': 2,
#   'SERVIÇOS DOMÉSTICOS': 3},
#  'Uf': {'ES': 0, 'PI': 1, 'RR': 2, 'SC': 3},
#  'FundationDate': {1990: 0, 1991: 1, 2001: 2, 2015: 3}}
# {'ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS': 0, 'CONSTRUÇÃO': 1, 'SAÚDE HUMANA E SERVIÇOS SOCIAIS': 2, 'SERVIÇOS DOMÉSTICOS': 3}
# {'ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS': 0}

# %% [markdown]
# ### End of optional one-hot encoding for feature

# %% [markdown]
# ## One-hot encoding for label

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_label_cat)
df_label = le.transform(df_label_cat) 

## demo
print (list(le.classes_))
print(list(df_label)[:10])
print(le.inverse_transform([0, 0, 1, 2]))
# Out:
# ['G1', 'G2', 'G3', 'G4', 'G5']
# [0, 0, 2, 2, 3, 1, 4, 3, 2, 0]
# ['G1' 'G1' 'G2' 'G3']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df_data, df_label, test_size=0.33, random_state=42)

# %%
display (X_train.head(3))
display (X_test.head(3))
display (y_train[:3])
display (y_test[:3])
# Out:
#                                              CnaeSession  Uf  FundationDate  \
# 23990                                           EDUCAÇÃO  MA           2015
# 8729   ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEME...  AP           1998
# 3451   ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...  SE           1997
#
#         Equity
# 23990  5320000
# 8729   1500000
# 3451   2320000
#                                              CnaeSession  Uf  FundationDate  \
# 33552  ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...  DF           1998
# 9427   ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...  SC           1998
# 199     ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  PI           1998
#
#         Equity
# 33552  2320000
# 9427   1500000
# 199    2320000
# array([3, 3, 2])
# array([4, 1, 2])

# %%
# specify the training parameters 
model = CatBoostClassifier(iterations=10, depth=4, learning_rate=1, 
                           loss_function='MultiClass', 
                           custom_metric='AUC', logging_level='Verbose')
#train the model
cat_features_index = [0,1,2]
model.fit(X_train, y_train, cat_features = cat_features_index)
# make the prediction using the resulting model
preds_class = model.predict(X_test)
preds_proba = model.predict_proba(X_test)
print("class = ", preds_class)
print("proba = ", preds_proba)
# Out:
# 0:	learn: -1.6087396	total: 197ms	remaining: 1.77s
# 1:	learn: -1.6086073	total: 323ms	remaining: 1.29s
# 2:	learn: -1.6081945	total: 463ms	remaining: 1.08s
# 3:	learn: -1.6076275	total: 608ms	remaining: 911ms
# 4:	learn: -1.6073794	total: 755ms	remaining: 755ms
# 5:	learn: -1.6069620	total: 890ms	remaining: 593ms
# 6:	learn: -1.6066075	total: 1.04s	remaining: 446ms
# 7:	learn: -1.6063936	total: 1.19s	remaining: 297ms
# 8:	learn: -1.6059271	total: 1.32s	remaining: 147ms
# 9:	learn: -1.6055691	total: 1.46s	remaining: 0us
# class =  [[0.]
#  [0.]
#  [0.]
#  ...
#  [1.]
#  [1.]
#  [3.]]
# proba =  [[0.21077529 0.20827489 0.18677959 0.1915883  0.20258193]
#  [0.20832244 0.20511616 0.19173491 0.19783419 0.1969923 ]
#  [0.21077529 0.20827489 0.18677959 0.1915883  0.20258193]
#  ...
#  [0.1994482  0.20476509 0.19768069 0.19695032 0.2011557 ]
#  [0.20457674 0.2057273  0.19568606 0.19975461 0.1942553 ]
#  [0.19478693 0.20047045 0.19867245 0.20736138 0.19870879]]

# %%
print (preds_proba[:10])
print (preds_class[:10])
# Out:
# [[0.21077529 0.20827489 0.18677959 0.1915883  0.20258193]
#  [0.20832244 0.20511616 0.19173491 0.19783419 0.1969923 ]
#  [0.21077529 0.20827489 0.18677959 0.1915883  0.20258193]
#  [0.20543028 0.21200809 0.19500605 0.18903901 0.19851657]
#  [0.19907474 0.2046388  0.19803312 0.195204   0.20304934]
#  [0.18699455 0.21430772 0.18935953 0.19891355 0.21042465]
#  [0.18281488 0.21172345 0.20598473 0.1975673  0.20190963]
#  [0.19734252 0.20421955 0.18418747 0.2122244  0.20202606]
#  [0.19843165 0.19458062 0.1937228  0.21824286 0.19502206]
#  [0.19648116 0.19665389 0.212594   0.19787995 0.196391  ]]
# [[0.]
#  [0.]
#  [0.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [3.]
#  [3.]
#  [2.]]

# %%
from sklearn.metrics import classification_report
print (classification_report(y_test, model.predict(X_test)))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.20      0.31      0.24      3317
#           1       0.20      0.35      0.26      3296
#           2       0.20      0.13      0.16      3343
#           3       0.19      0.16      0.18      3306
#           4       0.19      0.05      0.08      3238
#
# avg / total       0.20      0.20      0.18     16500

# %% [markdown]
# ## Model serialization

# %%
import pickle
my_pickle_name = 'model.pkl'

# %%
pickle.dump([le, model], open(my_pickle_name, 'wb'))

# %%
encoder, modelCatBoost = pickle.load(open(my_pickle_name, 'rb'))
###encoder.classes_

# %%
# myPickle_le = 'pickle_le.pkl'
# pickle.dump(le, open(myPickle_le, 'wb'))

# myPickle_model = 'pickle_model.pkl'
# pickle.dump(model, open(myPickle_model, 'wb'))

# import catboost
# check = model.load_model("catBoostClass.mlmodel")

# %% [markdown]
# ## Output prediction with index and group

# %%
def getIndexAndGroup(data_input):
    my_predIndex = modelCatBoost.predict(data_input).astype('int').flatten() ## flatten for narray to list
    my_predGroup = encoder.inverse_transform(my_predIndex)
    print(my_predIndex, my_predGroup)
    return my_predIndex, my_predGroup

# %% [markdown]
# ## Input data for prediction

# %% [markdown]
# ### From test dataset

# %%
myInput = X_test[:10]
display(myInput)
# Out:
#                                              CnaeSession  Uf  FundationDate  \
# 33552  ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...  DF           1998
# 9427   ORGANISMOS INTERNACIONAIS E OUTRAS INSTITUIÇÕE...  SC           1998
# 199     ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  PI           1998
# 12447                  TRANSPORTE, ARMAZENAGEM E CORREIO  TO           1991
# 39488                           ALOJAMENTO E ALIMENTAÇÃO  RO           1997
# 42723                    SAÚDE HUMANA E SERVIÇOS SOCIAIS  PR           2010
# 10822  ATIVIDADES ADMINISTRATIVAS E SERVIÇOS COMPLEME...  MS           1992
# 49497                      OUTRAS ATIVIDADES DE SERVIÇOS  AP           1998
# 4144    ATIVIDADES PROFISSIONAIS, CIENTÍFICAS E TÉCNICAS  SE           1996
# 34018                           ALOJAMENTO E ALIMENTAÇÃO  PI           1997
#
#          Equity
# 33552   2320000
# 9427    1500000
# 199     2320000
# 12447   5320000
# 39488  15320000
# 42723   2320000
# 10822   1000000
# 49497  15320000
# 4144    2320000
# 34018   2320000

# %%
getIndexAndGroup(myInput)
# Out:
# [0 0 0 1 1 1 1 3 3 2] ['G1' 'G1' 'G1' 'G2' 'G2' 'G2' 'G2' 'G4' 'G4' 'G3']
# (array([0, 0, 0, 1, 1, 1, 1, 3, 3, 2]),
#  array(['G1', 'G1', 'G1', 'G2', 'G2', 'G2', 'G2', 'G4', 'G4', 'G3'],
#        dtype=object))

# %% [markdown]
# ### From manually input

# %%
dataInput = {'CnaeSession':'ALOJAMENTO E ALIMENTAÇÃO', 
             'Uf':'RO', 
             'FundationDate':'1997',
             'Equity':15320000,
            }

correcFeatOrder = ['CnaeSession', 'Uf', 'FundationDate', 'Equity']
df_dataInput = pd.DataFrame.from_dict([dataInput])[correcFeatOrder]

display(df_dataInput)
# Out:
#                 CnaeSession  Uf FundationDate    Equity
# 0  ALOJAMENTO E ALIMENTAÇÃO  RO          1997  15320000

# %%
getIndexAndGroup(df_dataInput)
# Out:
# [1] ['G2']
# (array([1]), array(['G2'], dtype=object))

# %% [markdown]
# ### From flask

# %%
url = "http://localhost:5000/model1"
data = json.dumps(dataInput)
print(data)
r = requests.post(url, data)

print(r.json())
# Out:
# {"CnaeSession": "ALOJAMENTO E ALIMENTA\u00c7\u00c3O", "Uf": "RO", "FundationDate": "1997", "Equity": 15320000}
# {'attempt': '144', 'predGroup': ['G2'], 'predIndex': [1]}

# %% [markdown]
# ### From heroku

# %%
# urlnew = "https://smartmodel1.herokuapp.com/model1"
# data = json.dumps(dataInput)
# print(data)
# r = requests.post(urlnew, data)
# print(r.json())

# %% [markdown]
# ### (Optional) Feature Importances

# %%
print (model.feature_importances_)
col = list(X_train)
df = pd.DataFrame({'imp': model.feature_importances_, 'col':col})
df = df.sort_values(['imp','col'], ascending=[True, False])
_ = df.plot(kind='barh', x='col', y='imp', figsize=(8,6))
# Out:
# [19.368336   37.3117264  34.1435422   9.17639541]
